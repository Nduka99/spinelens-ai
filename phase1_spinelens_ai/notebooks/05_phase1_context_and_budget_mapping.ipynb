# %% [markdown]
# # 03 - Phase 1 Context and Budget Mapping
#
# Purpose: translate the GBP 1,000,000 Phase 1 proposal into measurable AI-layer questions.
#
# This notebook should map each budget line to the evidence SpineLens needs to produce.

# %% [markdown]
# ## Core Question
#
# Where does the city-to-B-KQ route become illegible, and which Phase 1 interventions improve clarity fastest?

# %%
from pathlib import Path
import sys

root_candidates = (Path.cwd(), Path.cwd() / 'phase1_spinelens_ai', *Path.cwd().parents)
PROJECT_ROOT = next(path for path in root_candidates if (path / 'src' / 'spinelens').exists())
SRC = PROJECT_ROOT / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

from spinelens.config import PHASE1_BUDGET_LINES, phase1_budget_total

PHASE1_BUDGET_LINES, phase1_budget_total()
